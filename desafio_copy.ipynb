# %%
import numpy as np
import pandas as pd

# %%
import time

# %%
from functions import religiao, renda_familiar, obito, meios_transporte, sexo_biologico, doencas_condicoes, identidade_genero
from functions import ids_repetidas, luz_eletrica, em_situacao_de_rua, meios_comunicacao, possui_plano_saude, vulnerabilidade_social
from functions import fam_aux_bra, cria_matr_cre, data_at_cad, data_nasc, data_cad, updated_at, em_caso_doenca_procura
from functions import raca_cor, altura, peso, pressao_sistolica, pressao_diastolica, situ_prof

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
start_time = time.time()

# %%
df = pd.read_csv('~\desafio\dados_ficha_a_desafio.csv', encoding = 'utf-8', encoding_errors = 'strict')

# %%
#### ITEM 0

# %%
sexo_biologico(df)

# %%
df.head()
# Out:
#                             id_paciente sexo_biologico  obito  \
# 0  cd6daa6e-038d-4952-af29-579e62e07f97           male      0
# 1  ad6cecb2-3a44-49ab-b2f3-6f9ffc2e2ec7           male      0
# 2  54e834e7-e722-4daa-8909-cf917a1247e6           male      0
# 3  c6a71e5e-0933-48d1-9d5a-8f448dc37f71         female  False
# 4  d5262a3c-e5d3-4195-a46b-0acd2533e1d6           male      0
#
#             bairro raca_cor                          ocupacao      religiao  \
# 0  Parada de Lucas   Branca                     Não se aplica  Sem religião
# 1      Cidade Nova    Parda         Assistente Administrativo    Evangélica
# 2       Santa cruz    Parda                     Não se aplica      Católica
# 3            Bangu   Branca  Representante Comercial Autônomo  Sem religião
# 4       Santíssimo   Branca               Técnico Eletricista         Outra
#
#   luz_eletrica            data_cadastro            escolaridade nacionalidade  \
# ...

# %%
#### item 1

# %%
ids_repetidas(df)

# %%
### ITEM 2

# %%
obito(df)

# %%
df['obito'].value_counts()
# Out:
# obito
# 0    98561
# 1     1439
# Name: count, dtype: int64

# %%
### ITEM 3

# %%
df['religiao'].value_counts()
# Out:
# religiao
# Sem religião                          35119
# Católica                              28348
# Outra                                 18714
# Evangélica                            14798
# Espírita                               1974
# Religião de matriz africana             731
# Não                                     174
# Budismo                                  81
# Judaísmo                                 32
# Islamismo                                 8
# Acomp. Cresc. e Desenv. da Criança        7
# Candomblé                                 6
# ESB ALMIRANTE                             5
# 10 EAP 01                                 1
# ORQUIDEA                                  1
# Sim                                       1
# Name: count, dtype: int64

# %%
religiao(df)

# %%
### ITEM 4

# %%
luz_eletrica(df)

# %%
df['luz_eletrica'].value_counts()
# Out:
# luz_eletrica
# 1    93615
# 0     6385
# Name: count, dtype: int64

# %%
### ITEM 5

# %%
df['em_situacao_de_rua'].value_counts()
# Out:
# em_situacao_de_rua
# 0        91910
# False     7974
# 1          116
# Name: count, dtype: int64

# %%
em_situacao_de_rua(df)

# %%
### ITEM 6

# %%
meios_transporte(df)

# %%
df['meios_transporte'].value_counts().shape
# Out:
# (33,)

# %%
############### ITEM 7

# %%
df['doencas_condicoes'].value_counts().shape
# Out:
# (277,)

# %%
doencas_condicoes(df)

# %%
### ITEM 8

# %%
df['identidade_genero'].value_counts()
# Out:
# identidade_genero
# Não                            69781
# Cis                            21033
# Mulher transexual               3792
# Homem transexual                1939
# Outro                           1343
# Heterossexual                   1025
# Sim                               50
# Homossexual (gay / lésbica)       44
# Travesti                          35
# Bissexual                          6
# Name: count, dtype: int64

# %%
identidade_genero(df)

# %%
### ITEM 9

# %%
df['meios_comunicacao'].value_counts().shape
# Out:
# (325,)

# %%
meios_comunicacao(df)

# %%
#### ITEM 10

# %%
df['possui_plano_saude'].value_counts()
# Out:
# possui_plano_saude
# 0        84459
# 1         7628
# False     7442
# True       471
# Name: count, dtype: int64

# %%
possui_plano_saude(df)

# %%
### ITEM 11

# %%
df['em_caso_doenca_procura'].value_counts().shape
# Out:
# (168,)

# %%
em_caso_doenca_procura(df)

# %%
### ITEM 12

# %%
df['vulnerabilidade_social'].value_counts()
# Out:
# vulnerabilidade_social
# 0        90144
# 1         5145
# False     4046
# True       665
# Name: count, dtype: int64

# %%
vulnerabilidade_social(df)

# %%
### ITEM 13

# %%
df['familia_beneficiaria_auxilio_brasil'].value_counts()
# Out:
# familia_beneficiaria_auxilio_brasil
# 0        77219
# 1        11833
# False     9433
# True      1515
# Name: count, dtype: int64

# %%
fam_aux_bra(df)

# %%
### ITEM 14

# %%
df['crianca_matriculada_creche_pre_escola'].value_counts()
# Out:
# crianca_matriculada_creche_pre_escola
# 0        54744
# 1        27291
# False    13633
# True      4332
# Name: count, dtype: int64

# %%
cria_matr_cre(df)

# %%
##ITEM 15

# %%
df['frequenta_escola'].value_counts()
# Out:
# frequenta_escola
# 0    84181
# 1    15819
# Name: count, dtype: int64

# %%
### item 16

# %%
df['orientacao_sexual'].value_counts()
# Out:
# orientacao_sexual
# Heterossexual                  93837
# Homossexual (gay / lésbica)     4132
# Outro                           1314
# Bissexual                        717
# Name: count, dtype: int64

# %%
### item 17

# %%
df['raca_cor'].value_counts()
# Out:
# raca_cor
# Parda       50856
# Branca      35113
# Preta       11373
# Amarela      2619
# Indígena       36
# Não             3
# Name: count, dtype: int64

# %%
raca_cor(df)

# %%
###item 18

# %%
df['nacionalidade'].value_counts()
# Out:
# nacionalidade
# Brasileira      99660
# Estrangeiro       307
# Naturalizado       33
# Name: count, dtype: int64

# %%
###item 19

# %%
df['tipo'].value_counts()
# Out:
# tipo
# historico    92232
# rotineiro     7768
# Name: count, dtype: int64

# %%
##### ITEM 20

# %%
df['bairro'].value_counts()
# Out:
# bairro
# Campo Grande                                        5873
# Santa cruz                                          4297
# Bangu                                               3963
# Realengo                                            3382
# Guaratiba                                           2856
# Paciência                                           2116
# Jacarepaguá                                         1889
# Tijuca                                              1734
# Anil                                                1727
# Irajá                                               1629
# Ramos                                               1510
# Senador Camará                                      1446
# Cosmos                                              1378
# Inhoaíba                                            1357
# Taquara                                             1343
# Pavuna                                              1323
# ...

# %%
### item 21: ver datas

# %%
data_at_cad(df)

# %%
data_nasc(df)

# %%
data_cad(df)

# %%
updated_at(df)

# %%
#### item 22: ver colunas com números
# altura
# peso
# pressao_sistolica
# pressao_diastolica
# n_atendimentos_atencao_primaria
# n_atendimentos_hospital

# %%
###altura

# %%
altura(df)

# %%
df[df['altura'] > 258.0]
# Out:
# Empty DataFrame
# Columns: [id_paciente, sexo_biologico, obito, bairro, raca_cor, ocupacao, religiao, luz_eletrica, data_cadastro, escolaridade, nacionalidade, renda_familiar, data_nascimento, em_situacao_de_rua, frequenta_escola, meios_transporte, doencas_condicoes, identidade_genero, meios_comunicacao, orientacao_sexual, possui_plano_saude, em_caso_doenca_procura, situacao_profissional, vulnerabilidade_social, data_atualizacao_cadastro, familia_beneficiaria_auxilio_brasil, crianca_matriculada_creche_pre_escola, altura, peso, pressao_sistolica, pressao_diastolica, n_atendimentos_atencao_primaria, n_atendimentos_hospital, updated_at, tipo]
# Index: []

# %%
###peso

# %%
peso(df)

# %%
df[df['peso']>200.0]
# Out:
# Empty DataFrame
# Columns: [id_paciente, sexo_biologico, obito, bairro, raca_cor, ocupacao, religiao, luz_eletrica, data_cadastro, escolaridade, nacionalidade, renda_familiar, data_nascimento, em_situacao_de_rua, frequenta_escola, meios_transporte, doencas_condicoes, identidade_genero, meios_comunicacao, orientacao_sexual, possui_plano_saude, em_caso_doenca_procura, situacao_profissional, vulnerabilidade_social, data_atualizacao_cadastro, familia_beneficiaria_auxilio_brasil, crianca_matriculada_creche_pre_escola, altura, peso, pressao_sistolica, pressao_diastolica, n_atendimentos_atencao_primaria, n_atendimentos_hospital, updated_at, tipo]
# Index: []

# %%
### pressao_sistolica

# %%
pressao_sistolica(df)

# %%
df[df['pressao_sistolica'] > 250.0]
# Out:
# Empty DataFrame
# Columns: [id_paciente, sexo_biologico, obito, bairro, raca_cor, ocupacao, religiao, luz_eletrica, data_cadastro, escolaridade, nacionalidade, renda_familiar, data_nascimento, em_situacao_de_rua, frequenta_escola, meios_transporte, doencas_condicoes, identidade_genero, meios_comunicacao, orientacao_sexual, possui_plano_saude, em_caso_doenca_procura, situacao_profissional, vulnerabilidade_social, data_atualizacao_cadastro, familia_beneficiaria_auxilio_brasil, crianca_matriculada_creche_pre_escola, altura, peso, pressao_sistolica, pressao_diastolica, n_atendimentos_atencao_primaria, n_atendimentos_hospital, updated_at, tipo]
# Index: []

# %%
## pressao_diastolica

# %%
pressao_diastolica(df)

# %%
df[df['pressao_diastolica']> 200.0]
# Out:
# Empty DataFrame
# Columns: [id_paciente, sexo_biologico, obito, bairro, raca_cor, ocupacao, religiao, luz_eletrica, data_cadastro, escolaridade, nacionalidade, renda_familiar, data_nascimento, em_situacao_de_rua, frequenta_escola, meios_transporte, doencas_condicoes, identidade_genero, meios_comunicacao, orientacao_sexual, possui_plano_saude, em_caso_doenca_procura, situacao_profissional, vulnerabilidade_social, data_atualizacao_cadastro, familia_beneficiaria_auxilio_brasil, crianca_matriculada_creche_pre_escola, altura, peso, pressao_sistolica, pressao_diastolica, n_atendimentos_atencao_primaria, n_atendimentos_hospital, updated_at, tipo]
# Index: []

# %%
## n_atendimentos_atencao_primaria

# %%
df['n_atendimentos_atencao_primaria'].value_counts()
# Out:
# n_atendimentos_atencao_primaria
# 0     26226
# 5      6184
# 4      6118
# 6      6013
# 3      5821
# 7      5794
# 2      5665
# 8      5424
# 1      5173
# 9      4901
# 10     4338
# 11     3822
# 12     3225
# 13     2702
# 14     2182
# 15     1752
# 16     1290
# 17     1013
# 18      774
# 19      520
# 20      375
# 21      254
# 22      178
# 23       99
# 24       62
# 25       36
# 26       24
# 27       13
# 29        9
# 28        8
# 30        4
# 32        1
# Name: count, dtype: int64

# %%
## n_atendimentos_hospital

# %%
df['n_atendimentos_hospital'].value_counts()
# Out:
# n_atendimentos_hospital
# 0     46094
# 3      2600
# 2      2527
# 4      2514
# 1      2505
# 6      2451
# 5      2448
# 8      2389
# 7      2327
# 10     2296
# 9      2282
# 11     2192
# 12     2091
# 13     2013
# 14     1954
# 15     1789
# 16     1769
# 17     1684
# 18     1530
# 19     1386
# 20     1284
# 21     1277
# 22     1115
# 23     1095
# 24      940
# 25      821
# 26      774
# 27      722
# 28      608
# 29      561
# 30      534
# 31      458
# 32      416
# 33      375
# 34      329
# 35      264
# 36      229
# 37      220
# 39      177
# 38      163
# 40      115
# 42      109
# 41      103
# 43       90
# 44       58
# 45       52
# 47       48
# 46       47
# 48       40
# 49       28
# 50       22
# 51       18
# 53       16
# 58       10
# 54        9
# 57        8
# 52        7
# 56        4
# 55        4
# 61        3
# 68        1
# 77        1
# 65        1
# 62        1
# 59        1
# 60        1
# Name: count, dtype: int64

# %%
##### item 23 ocupacao

# %%
df['ocupacao'].value_counts()
# Out:
# ocupacao
# Não se aplica                                                                                                                               47000
# Vendedor de Comércio Varejista                                                                                                               3091
# Empregado Doméstico Diarista                                                                                                                 2328
# Administrador                                                                                                                                2236
# Vendedor Em Domicílio                                                                                                                        1878
# Manicure                                                                                                                                     1873
# ...

# %%
### item 24 escolaridade

# %%
df['escolaridade'].value_counts()
# Out:
# escolaridade
# Médio Completo               32704
# Fundamental Incompleto       21826
# Fundamental Completo         14301
# Alfabetizado                  8519
# Não sabe ler/escrever         8231
# Médio Incompleto              6434
# Superior completo             5904
# Superior incompleto           1887
# Especialização/Residência       88
# Mestrado                        70
# Doutorado                       36
# Name: count, dtype: int64

# %%
### item 25 renda familiar

# %%
df['renda_familiar'].value_counts(dropna=False)
# Out:
# renda_familiar
# 1 Salário Mínimo              43517
# 2 Salários Mínimos            33444
# 3 Salários Mínimos             9867
# 1/2 Salário Mínimo             4825
# 1/4 Salário Mínimo             3878
# 4 Salários Mínimos             2864
# Mais de 4 Salários Mínimos     1603
# Manhã                             1
# Internet                          1
# Name: count, dtype: int64

# %%
renda_familiar(df)

# %%
### item 26 situacao_profissional

# %%
df.columns.get_loc('situacao_profissional')
# Out:
# 22

# %%
situ_prof(df)

# %%
df['situacao_profissional'].value_counts()
# Out:
# situacao_profissional
# Emprego Formal              33307
# Não se aplica               18490
# Desempregado                17393
# Emprego Informal            12823
# Pensionista / Aposentado    10915
# Autônomo                     4876
# Outro                        1825
# Empregador                    371
# Name: count, dtype: int64

# %%
########################################################### df final

# %%
df.head()
# Out:
#                             id_paciente sexo_biologico  obito  \
# 0  cd6daa6e-038d-4952-af29-579e62e07f97           male      0
# 1  ad6cecb2-3a44-49ab-b2f3-6f9ffc2e2ec7           male      0
# 2  54e834e7-e722-4daa-8909-cf917a1247e6           male      0
# 3  c6a71e5e-0933-48d1-9d5a-8f448dc37f71         female      0
# 4  d5262a3c-e5d3-4195-a46b-0acd2533e1d6           male      0
#
#             bairro raca_cor                          ocupacao      religiao  \
# 0  Parada de Lucas   Branca                     Não se aplica  Sem religião
# 1      Cidade Nova    Parda         Assistente Administrativo    Evangélica
# 2       Santa cruz    Parda                     Não se aplica      Católica
# 3            Bangu   Branca  Representante Comercial Autônomo  Sem religião
# 4       Santíssimo   Branca               Técnico Eletricista         Outra
#
#    luz_eletrica       data_cadastro            escolaridade nacionalidade  \
# ...

# %%
### Criando um novo arquivo csv com a tabela tratada
df.to_csv('dados_ficha_a_desafio_TRATADA.csv')

# %%
end_time = time.time()
print(f'Tempo de execução:{end_time - start_time}.')
# Out:
# Tempo de execução:139.92985033988953.
